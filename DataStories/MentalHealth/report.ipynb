# %%
import pandas as pd
df = pd.read_csv('mental.csv')
cols = df.columns
head = df.head()
# Out:
# C:\Users\greyl\AppData\Local\Temp\ipykernel_14156\2935345461.py:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('mental.csv')

# %%
# american dataset
am_df = df[df['Code'].isin(['USA', 'AFG', 'GBR', 'THA'])]

# %%
# plotting 
import plotly.express as px
compare = ['Anxiety disorders (%)', 'Depression (%)']
am_df
fig = px.scatter(am_df, x='Year', y='Anxiety disorders (%)', color='Code')
# fig.update_xaxes(range=[2000, 2010])
fig.show()
