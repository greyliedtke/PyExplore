# %%
from pandas_datareader import wb
import matplotlib.pyplot as plt

dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'FR', 'GB', 'DK', 'NO', 'UA', 'RU'], start=2000, end=2022, freq='M')
print(dat.unstack().T.reset_index(0))
dat.unstack().T.reset_index(0).plot()
plt.title('GDP per capita')
plt.show()
# Out:
# country         level_0       Denmark        France        Norway  \
# year
# 1960     NY.GDP.PCAP.KD  18107.375929  11176.412754  19134.059878
# 1961     NY.GDP.PCAP.KD  19128.404422  11579.311373  20173.516372
# 1962     NY.GDP.PCAP.KD  20055.643682  12200.164706  20575.220612
# 1963     NY.GDP.PCAP.KD  20025.036753  12779.877746  21193.147842
# 1964     NY.GDP.PCAP.KD  21707.163723  13450.613077  22087.370187
# ...                 ...           ...           ...           ...
# 2017     NY.GDP.PCAP.KD  55735.764901  37694.083303  75610.649483
# 2018     NY.GDP.PCAP.KD  56563.488473  38291.865781  75953.581951
# 2019     NY.GDP.PCAP.KD  57553.131240  38912.331265  76005.224787
# 2020     NY.GDP.PCAP.KD  56202.165853  35785.967012  75017.156747
# 2021     NY.GDP.PCAP.KD  58585.507727  38210.218213  77544.033870
#
# country  Russian Federation      Ukraine  United Kingdom  United States
# year
# 1960                    NaN          NaN    14914.880761   19135.268182
# 1961                    NaN          NaN    15198.153421   19253.547329
# 1962                    NaN          NaN    15235.923699   20116.235124
# 1963                    NaN          NaN    15859.449114   20701.269947
# 1964                    NaN          NaN    16628.576083   21599.818705
# ...                     ...          ...             ...            ...
# 2017            9473.179688  2246.738525    46746.641890   58215.411628
# 2018            9739.900391  2336.976318    47231.336887   59600.053098
# 2019            9958.460938  2425.634521    47750.879662   60687.232258
# 2020            9711.417969  2350.399902    43166.155200   58060.313948
# 2021           10219.750977  2451.900879    46209.105175   61280.389602
#
# [62 rows x 8 columns]
