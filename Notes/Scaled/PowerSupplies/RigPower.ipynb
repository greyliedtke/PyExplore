# %%
v_heater = 48
r_heater = 120
i_heater = v_heater/r_heater
p_heater = v_heater*i_heater
print(f"Heater Current: {round(i_heater, 2)}, Power: {round(p_heater, 2)}")
# Out:
# Heater Current: 0.4, Power: 19.2

# %% [markdown]
# Fuel Nozzles
# Normal
# - 5
# - 7
# - 9.5
# Flowback
#
# ## Oil System
# - Target Pressure: 40 PSI
# - Target Flowrate: .280 liters/min
# - ![image.png](attachment:image.png)

# %% [markdown]
# Flow Sensor - https://www.omega.com/en-us/flow-instruments/flow-meters/paddlewheel-flow-meters/ftb300-series/p/FTB322
# Notes: 100 - 1000 ml/min flow sensor, 1/4 NPTF, 21535 pulses per liter, 1.585-15.85 gph
