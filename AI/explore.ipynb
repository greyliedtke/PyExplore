# %%
import matplotlib.pyplot as plt 

# list of css colors  
colors = ['#d3f2c7', '#3d3d3d', '#80aaff', '#A3A3C2', '#CFA0E3', '#808080', '#F4C2C2'] 

# plot the css colors  
plt.bar(range(len(colors)),[1]*len(colors), color=colors)
plt.xticks(range(len(colors)), colors, rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x20fab605d50>,
# ...
#  [Text(0, 0, '#d3f2c7'),
#   Text(1, 0, '#3d3d3d'),
#   Text(2, 0, '#80aaff'),
#   Text(3, 0, '#A3A3C2'),
#   Text(4, 0, '#CFA0E3'),
#   Text(5, 0, '#808080'),
#   Text(6, 0, '#F4C2C2')])
